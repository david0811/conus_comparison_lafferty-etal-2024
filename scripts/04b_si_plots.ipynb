# %%
pu.plot_mean_and_uncertainty(
    plot_metric_ids=['avg_tasmax', 'avg_tasmin', 'sum_pr'],
    plot_col='slope',
    proj_slice='2015-2100',
    analysis_type='trends',
    rel_metric_ids = ['sum_pr'],
    summary_title="a) Ensemble mean trends in annual metrics (2015-2100)",
)

# %%
pu.plot_mean_and_uncertainty(
    plot_metric_ids=['max_tasmax', 'min_tasmin', 'max_pr'],
    plot_col='100yr_return_level',
    return_period=100,
    proj_slice='1950-2100',
    analysis_type='extreme_value',
    summary_title="a) Ensemble mean change in 100-year return level (2075 from 1975; non-stationary GEV)",
    stat_str = "nonstat_scale",
    time_strs = {'max_tasmax':'diff_2075-1975', 'min_tasmin':'diff_2075-1975', 'max_pr':'diff_2075-1975'}
)
